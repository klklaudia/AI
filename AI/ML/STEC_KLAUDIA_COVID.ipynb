# %% [markdown]
# https://covid19datahub.io/articles/python.html

# %% [markdown]
# https://covid19datahub.io/articles/docs.html

# %%
pip install covid19dH

# %%
from covid19dh import covid19
x, src = covid19()
#x, src = covid19(raw = False) # left NaN values - ???
# Out:
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.

# %%
src#[['data_type', 'url']]
# Out:
#     iso_alpha_3 administrative_area_level  \
# 0           ABW                         1
# 1           ABW                         1
# 742         ABW                         1
# 743         ABW                         1
# 744         ABW                         1
# ..          ...                       ...
# 757         ZWE                         1
# 758         ZWE                         1
# 759         ZWE                         1
# 760         ZWE                         1
# 761         ZWE                         1
#
#                                data_type  \
# 0                               latitude
# 1                              longitude
# 742                               deaths
# 743                            confirmed
# 744                                tests
# ..                                   ...
# 757  international_movement_restrictions
# 758                       testing_policy
# 759                      contact_tracing
# ...

# %%
for country in src.iso_alpha_3.unique():
  print(f'{country}: {len(src[src.iso_alpha_3 == country].data_type.unique())}') # biggest val only
# Out:
# ABW: 18
# AFG: 18
# AGO: 18
# AIA: 8
# ALB: 18
# AND: 18
# ARE: 18
# ARG: 19
# ARM: 8
# ASM: 5
# ATG: 8
# AUS: 21
# AUT: 20
# AZE: 18
# BDI: 18
# BEL: 21
# BEN: 18
# BES: 7
# BFA: 18
# BGD: 18
# BGR: 20
# BHR: 18
# BHS: 18
# BIH: 18
# BLR: 18
# BLZ: 18
# BMU: 18
# BOL: 20
# BRA: 18
# BRB: 18
# BRN: 18
# BTN: 18
# BWA: 18
# CAF: 18
# CAN: 20
# CHE: 20
# CHL: 20
# CHN: 17
# CIV: 18
# CMR: 18
# COD: 17
# COG: 18
# COK: 6
# COL: 18
# COM: 8
# CPV: 17
# CRI: 18
# CUB: 18
# CUW: 8
# CYM: 8
# CYP: 20
# CZE: 20
# DEU: 19
# DJI: 18
# DMA: 18
# DNK: 20
# DOM: 18
# DZA: 19
# ECU: 18
# EGY: 18
# ERI: 17
# ESP: 20
# EST: 20
# ETH: 18
# FIN: 20
# FJI: 18
# FLK: 6
# FRA: 20
# FRO: 18
# FSM: 6
# GAB: 18
# GBR: 19
# GEO: 18
# GGY: 4
# GHA: 18
# GIB: 8
# GIN: 18
# GLP: 9
# GMB: 18
# GNB: 8
# GNQ: 8
# GRC: 18
# GRD: 18
# GRL: 15
# GTM: 18
# GUF: 9
# GUM: 16
# GUY: 18
# HKG: 18
# HND: 17
# HRV: 19
# HTI: 18
# HUN: 19
# IDN: 18
# IMN: 7
# IND: 18
# IRL: 20
# IRN: 18
# IRQ: 18
# ISL: 20
# ISR: 20
# ...

# %%
src.title.unique() # which are reliable?
# Out:
# array(['CIA - Central Intelligence Agency',
#        'Johns Hopkins Center for Systems Science and Engineering',
#        'Our World in Data', 'Oxford COVID-19 Government Response Tracker',
#        'World Bank Open Data', 'The New York Times', 'Covid19data.com.au',
#        'Federal Ministry of Social Affairs, Health, Care and Consumer Protection, Austria',
#        'Epistat, Belgian Infectious Diseases',
#        'Monitoring the number of COVID-19 cases and deaths in Brazil at municipal and federative units level',
#        'Public Health Infobase, Government of Canada',
#        'Federal Office of Public Health FOPH',
#        'Swiss Federal Statistical Office',
#        'Ministerio de Ciencia, TecnologÃ\xada, Conocimiento e InnovaciÃ³n',
#        'World Health Organization',
#        'Ministerio de Salud y ProtecciÃ³n Social de Colombia',
#        'Ministery of Health of Czech Republic', 'Robert Koch-Institut',
#        'Wikipedia', 'SantÃ© publique France',
# ...

# %%
src[src.iso_alpha_3 == 'POL'].title.unique()
# wordwide data or - objective, not focused
# country institution? - focused mayby subjective and hideing/increasing
# +how they managed covid
# Out:
# array(['Johns Hopkins Center for Systems Science and Engineering',
#        'Our World in Data', 'Oxford COVID-19 Government Response Tracker',
#        'World Bank Open Data'], dtype=object)

# %%
x
# Out:
#              id       date  confirmed  deaths  recovered  tests  vaccines  \
# 65898  0094b645 2020-01-03        NaN     NaN        NaN    NaN       NaN
# 65899  0094b645 2020-01-04        NaN     NaN        NaN    NaN       NaN
# 65900  0094b645 2020-01-05        NaN     NaN        NaN    NaN       NaN
# 65901  0094b645 2020-01-06        NaN     NaN        NaN    NaN       NaN
# 65902  0094b645 2020-01-07        NaN     NaN        NaN    NaN       NaN
# ...         ...        ...        ...     ...        ...    ...       ...
# 24123  fd169ad6 2023-02-23        NaN     NaN    21285.0    NaN       NaN
# 24124  fd169ad6 2023-02-24        NaN     NaN    21286.0    NaN       NaN
# 24125  fd169ad6 2023-02-25        NaN     NaN    21288.0    NaN       NaN
# 24126  fd169ad6 2023-02-26        NaN     NaN    21293.0    NaN       NaN
# 24127  fd169ad6 2023-02-27        NaN     NaN    21294.0    NaN       NaN
#
#        people_vaccinated  people_fully_vaccinated  hosp  ...  iso_alpha_3  \
# ...
